# %%
import pandas as pd

# %%
publications = ['CISP-BEMI2024', 'CISP-BEMI2025', 'AICS2025', 'AICS2025', 'IEMS2026', 'Elsevier2026']
status = ['Published', 'Published', 'Published', 'Published', 'Published', 'Under Review']
fa_Status = ['yes', 'yes', 'yes', 'no', 'yes', 'yes']
filename = ['CISP_BMEI_2024_SLAM.pdf', 'CISP_BMEI_2025_Sicheng.pdf', 'AICS2025_Sicheng.pdf', 'AICS2025_Rong.pdf', 'iemss2026_Glacier_3D_Sicheng.pdf', '2026Elsevier_Sicheng.pdf']

# %%
df = pd.DataFrame({
    "publication": publications,
    "status": status,
    "First Author Status": fa_Status,
    "filename": filename
})
df
# df.to_csv("output.csv", index=False)
# Out:
#      publication        status First Author Status  \
# 0  CISP-BEMI2024     Published                 yes
# 1  CISP-BEMI2025     Published                 yes
# 2       AICS2025     Published                 yes
# 3       AICS2025     Published                  no
# 4       IEMS2026     Published                 yes
# 5   Elsevier2026  Under Review                 yes
#
#                            filename
# 0           CISP_BMEI_2024_SLAM.pdf
# 1        CISP_BMEI_2025_Sicheng.pdf
# 2              AICS2025_Sicheng.pdf
# 3                 AICS2025_Rong.pdf
# 4  iemss2026_Glacier_3D_Sicheng.pdf
# 5          2026Elsevier_Sicheng.pdf

# %%
df.to_csv("paper_list.csv", index=False)
